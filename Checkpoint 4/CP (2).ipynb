# %% [markdown]
# # **Analisis Popularitas Drama Korea Berdasarkan Rank, Popularitas, *Screen Writer*, dan Sutradara (2015–2023)**
# ---
# **Nama:** Noor Hamsyah Pratama
# **NIM:** 2509116046
# **Kelas:** B'2025

# %% [markdown]
# # **Import Library**
# ----

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Memuat Dataset**
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/korean_drama.csv'

df = pd.read_csv(path)
df
# Out:
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# 1748  1e7f7f2fa45d4240b8bb585ca13040f0        Enchanting Neighbor  2015
# 1749  142a09741fdd4daa878d6ae007201e43              Iron Lady Cha  2015
# 1750  9170c31a02014b56bb4cec2105086f00       The Family Is Coming  2015
# 1751  c19353bdbc7a43ae98b27db202e7c908              Crow Building  2015
#
#                                director                         screenwriter  \
# ...

# %% [markdown]
# # 1.**Business Understanding**
# ---

# %% [markdown]
# ## V **Business Objective** V

# %% [markdown]
# Industri Drama Korea berkembang pesat dengan banyaknya judul yang dirilis setiap tahun, sehingga persaingan semakin tinggi. Untuk menentukan drama yang populer dan layak diprioritaskan, diperlukan analisis data, bukan hanya tren sesaat. Dengan dataset ini menyediakan informasi judul drama, tahun rilis, dan sutradara, serta indikator popularitas berupa peringkat dan nilai popularitas. Data tersebut dapat digunakan untuk memahami tingkat popularitas drama secara objektif.
#
#
# Tujuan bisnis dari analisis ini adalah untuk:
# 1. Memahami faktor-faktor yang memengaruhi popularitas Drama Korea berdasarkan data.
# 2. Mengidentifikasi drama yang memiliki tingkat popularitas tinggi.
# 3. Mendukung pengambilan keputusan bisnis dalam rekomendasi dan promosi konten.

# %% [markdown]
# ## V **Assess Situation** V
#
# Analisis ini memiliki beberapa tantangan, yaitu belum adanya analisis terstruktur untuk mengidentifikasi popularitas Drama Korea berdasarkan data yang tersedia, serta kesulitan dalam menentukan sutradara yang paling dominan sehingga pengambilan keputusan terkait prioritas dan promosi konten masih cenderung subjektif. Namun demikian, tersedia peluang dari dataset ini yang memuat informasi judul, tahun rilis, sutradara, serta juga indikator popularitas dengan peringkat dan nilai popularitas sehingga memungkinkan dilakukan analisis pola popularitas secara tidak langsung dan berbasis data. Di sisi lain, analisis ini juga memiliki keterbatasan, karena popularitas tidak dapat diukur secara langsung serta tidak mencakup faktor eksternal seperti tren global, media sosial, dan strategi pemasaran, sehingga interpretasi hasil sangat bergantung pada asumsi dan pendekatan analisis yang digunakan.

# %% [markdown]
# ## V **Analytic Goals** V
# Tujuan analitik dari analisis ini adalah:
#
# 1. Menganalisis tingkat popularitas Drama Korea berdasarkan nilai peringkat dan popularitas.
# 2. Mengidentifikasi sutradara yang paling banyak terlibat dalam produksi dengan nilai rank dan pop yang tinggi sebagai indikator popularitas sutradara.
# 3. Menganalisis konsistensi kemunculan sutradara dari tahun ke tahun pada drama populer untuk melihat pola popularitas yang berkelanjutan.
# 4. Mengidentifikasi pola kolaborasi *screen writer* dan sutradara pada drama dengan tingkat popularitas tinggi.

# %% [markdown]
# ## V **Project Plan** V
#
# 1. Mengumpulkan dan memilih data menggunakan dataset ini yang memuat informasi *screen writer*, sutradara, dan tahun rilis, serta nilai rank dan pop.
# 2. Melakukan pengolahan data melalui proses pembersihan, pengelompokan, dan transformasi untuk mendukung analisis.
# 3. Menganalisis hubungan antara *screen writer*, sutradara, dan indikator popularitas (rank dan pop).
# 4. Menyimpulkan hasil analisis untuk memberikan gambaran pola popularitas Drama Korea.

# %% [markdown]
# # 2.**Data Understanding**
# ---

# %% [markdown]
# ## V **Deskripsi Data** V

# %% [markdown]
# ###  **Struktur Data (Informasi Lanjutan)**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1752 entries, 0 to 1751
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kdrama_id     1752 non-null   object
#  1   drama_name    1752 non-null   object
#  2   year          1752 non-null   int64
#  3   director      1036 non-null   object
#  4   screenwriter  959 non-null    object
#  5   country       1752 non-null   object
#  6   type          1752 non-null   object
#  7   tot_eps       1752 non-null   int64
#  8   duration      1728 non-null   float64
#  9   start_dt      1752 non-null   object
#  10  end_dt        1752 non-null   object
#  11  aired_on      1520 non-null   object
#  12  org_net       1344 non-null   object
#  13  content_rt    1752 non-null   object
#  14  synopsis      1584 non-null   object
#  15  rank          1752 non-null   int64
#  16  pop           1752 non-null   int64
# dtypes: float64(1), int64(4), object(12)
# ...

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 1752 Baris dan 17 Kolom.
#
# ---
# 1. 'kdrama_id'
#     * Jumlah baris : 1752
#     * Tipe Data : object
#     * Deskripsi : ID unik untuk setiap drama
#
# 2. 'drama_name'
#     * Jumlah baris : 1752
#     * Tipe Data : object
#     * Deskripsi : Judul drama
#
# 3. 'year'
#     * Jumlah baris : 1752
#     * Tipe Data : int64
#     * Deskripsi : Tahun rilis drama
#
# 4. 'director'
#     * Jumlah baris : 1036
#     * Tipe Data : object
#     * Deskripsi : Nama sutradara
#
# 5. 'screenwriter'
#     * Jumlah baris : 959
#     * Tipe Data : object
#     * Deskripsi : Nama penulis skenario
#
# 6. 'country'
#     * Jumlah baris : 1752
#     * Tipe Data : object
#     * Deskripsi : Negara asal produksi drama
#
# 7. 'type'
#     * Jumlah baris : 1752
#     * Tipe Data : object
#     * Deskripsi : Jenis drama
#
#
# 8. 'tot_eps'
#     * Jumlah baris : 1752
#     * Tipe Data : int64
#     * Deskripsi : Total jumlah episode setiap drama
#
# 9. 'duration'
#     * Jumlah baris : 1728
#     * Tipe Data : float64
#     * Deskripsi : Durasi Drama
#
# 10. 'start_dt'
#     * Jumlah baris : 1752
#     * Tipe Data : object
#     * Deskripsi : Tanggal mulai penayangan drama
#
# 11. 'end_dt'
#     * Jumlah baris : 1752
#     * Tipe Data : object
#     * Deskripsi : Tanggal selesai penayangan drama
#
# 12. 'aired_on'
#     * Jumlah baris : 1520
#     * Tipe Data : object
#     * Deskripsi : Hari penayangan drama
#
# 13. 'org_net'
#     * Jumlah baris : 1344
#     * Tipe Data : object
#     * Deskripsi : Jaringan/platform penayangan
#
# 14. 'content_rt'
#     * Jumlah baris : 1752
#     * Tipe Data : object
#     * Deskripsi : Klasifikasi usia atau rating konten
#
# 15. 'synopsis'
#     * Jumlah baris : 1584
#     * Tipe Data : object
#     * Deskripsi : Ringkasan cerita drama
#
# 16. 'rank'
#     * Jumlah baris : 1752
#     * Tipe Data : int64
#     * Deskripsi : Peringkat drama
#
# 17. 'pop'
#     * Jumlah baris : 1752
#     * Tipe Data : int64
#     * Deskripsi : skor atau indeks popularitas drama

# %% [markdown]
# ### **Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#                                kdrama_id     drama_name         year  \
# count                               1752           1752  1752.000000
# unique                              1752           1752          NaN
# top     c19353bdbc7a43ae98b27db202e7c908  Crow Building          NaN
# freq                                   1              1          NaN
# mean                                 NaN            NaN  2019.006849
# std                                  NaN            NaN     2.317455
# min                                  NaN            NaN  2015.000000
# 25%                                  NaN            NaN  2017.000000
# 50%                                  NaN            NaN  2019.000000
# 75%                                  NaN            NaN  2021.000000
# max                                  NaN            NaN  2023.000000
#
#               director     screenwriter      country   type      tot_eps  \
# ...

# %% [markdown]
# 1. count
# Berdasarkan data, total baris adalah 1752. maka dapat disimpulkan bahwa:
# * kolom 'director' ada 716 data yang hilang (1752-1036)
# * kolom 'screenwriter' ada 793 data yang hilang (1752-959)
# * kolom 'duration' ada 24 data yang hilang (1752-1728)
# * kolom 'aired_on' ada 232 data yang hilang (1752-1520)
# * kolom 'org_net' ada 408 data yang hilang (1752-1344)
# * kolom 'synopsis' ada 168 data yang hilang (1752-1584)
#
#   Dari keterangan diatas dapat dikatakan bahwa kolom 'director', 'screenwriter', 'duration', 'aired_on', 'org_net', dan 'synopsis' terdapat *missing values*, sementara kolom lainnya lengkap (1752 data).
# ---
# 2. Mean dan Median(50%)
#
# **'year'**
# * mean = 2019
# * median = 2019
# Nilai mean dan median yang sama menunjukkan bahwa data tahun rilis drama terdistribusi relatif simetris. Mayoritas drama korea dalam dataset ini diproduksi sekitar tahun 2019, menandakan fokus data pada era modern drama korea.
#
# **'tot_eps'**
# * mean = 19
# * median = 12
# Nilai rata-rata jauh lebih besar dari median, hal ini menandakan adanya drama dengan jumlah episode sangat banyak yang menarik nilai mean ke atas. Mayoritas drama memiliki sekitar 12 episode, namun keberadaan drama panjang (long-running series) menyebabkan distribusi data condong ke kanan (right-skewed).
#
# **'duration'**
# * mean = 2149,79
# * median = 1800
# Mean lebih besar dari median, menunjukkan bahwa terdapat beberapa drama dengan total durasi tayang yang sangat panjang. Mayoritas drama memiliki durasi total sekitar 1800 menit, sedangkan nilai ekstrem menyebabkan rata-rata meningkat.
#
# **'rank'**
# * mean = 22248
# * median = 6266
# Perbedaan yang sangat signifikan antara mean dan median menunjukkan bahwa sebagian besar drama memiliki ranking cukup baik, namun terdapat sejumlah kecil drama dengan ranking sangat buruk (nilai besar) yang menarik rata-rata secara drastis.
#
# **'pop'**
# * mean = 22154
# * median = 3699
# Nilai mean jauh lebih besar daripada median, menandakan bahwa hanya sedikit drama yang sangat populer, sementara mayoritas drama memiliki tingkat popularitas yang relatif rendah.
#
# ---
# 3. Min dan Max
#
# **'year'**
# * Min = 2015
# * Max = 2023
# Rentang tahun masih logis dan konsisten, mencerminkan periode rilis drama dalam kurun waktu kurang lebih 9 tahun terakhir.
#
# **'tot_eps'**
# * Min = 1
# * Max = 150
# Jumlah episode maksimum sebesar 150 episode perlu divalidasi lebih lanjut, karena kemungkinan merupakan drama harian atau serial jangka panjang, bukan format drama korea reguler (mini series).
#
# **'duration'**
# * Min = 60
# * Max = 9180
# Rentang durasi yang sangat lebar menunjukkan variasi format drama, mulai dari drama pendek hingga serial dengan total durasi sangat panjang.
#
# **'rank'**
# * Min = 9
# * Max = 99999
# Nilai ranking maksimum yang sangat besar menunjukkan adanya drama dengan performa sangat rendah.
#
# **'pop'**
# * Min = 1
# * Max = 99999
# Rentang popularitas yang ekstrem menunjukkan kesenjangan besar antara drama yang kurang dikenal dan drama yang sangat populer.
#
# ---
# 4. Standar Deviasi (std)
#
# **'year'**
# * mean = 2019
# * std = 2,31
# Standar deviasi yang kecil menunjukkan bahwa tahun rilis drama cukup terkonsentrasi dan tidak menyebar jauh.
#
# **'tot_eps'**
# * mean = 19
# * std = 25,62
# Nilai standar deviasi yang lebih besar dari mean menunjukkan variasi jumlah episode yang sangat tinggi, menandakan ketidakhomogenan format episode antar drama.
#
# **'duration'**
# * mean = 2149,79
# * std = 1532,13
# Standar deviasi yang tinggi (kurang lebih 71% dari mean) menunjukkan bahwa total durasi drama sangat bervariasi, dari drama singkat hingga sangat panjang.
#
# **'rank'**
# * mean = 22248
# * std = 27689
# Nilai standar deviasi yang lebih besar dari mean mengindikasikan ketidakstabilan ranking serta dominasi nilai ekstrem dalam data.
#
# **'pop'**
# * mean = 22154
# * std = 37777
# Standar deviasi yang jauh lebih besar dari mean menunjukkan bahwa popularitas drama sangat tidak merata, dengan perbedaan tajam antara drama biasa dan drama yang sangat populer.

# %% [markdown]
# ## V **Verifikasi Kualitas Data** V

# %% [markdown]
# ### **Cek Tipe Data**

# %%
df.dtypes
# Out:
# kdrama_id        object
# drama_name       object
# year              int64
# director         object
# screenwriter     object
# country          object
# type             object
# tot_eps           int64
# duration        float64
# start_dt         object
# end_dt           object
# aired_on         object
# org_net          object
# content_rt       object
# synopsis         object
# rank              int64
# pop               int64
# dtype: object

# %% [markdown]
# 1. Object
# Kolom yang bertipe object antara lain:
# * 'kdrama_id'
# * 'drama_name'
# * 'director'
# * 'screenwriter'
# * 'country'
# * 'type'
# * 'start_dt'
# * 'end_dt'
# * 'aired_on'
# * 'org_net'
# * 'content_rt'
# * 'synopsis'
#
# Kolom bertipe object menunjukkan bahwa data bersifat kategorikal atau teks, seperti identitas dan nama drama, informasi kreator (sutradara, penulis), negara asal, jenis drama, informasi tanggal tayang yang masih disimpan sebagai string, deskripsi singkat (sinopsis).
#
# ---
# 2. Integer
# Kolom yang bertipe int64 antara lain:
# * 'year'
# * 'tot_eps'
# * 'rank'
# * 'pop'
#
# Kolom bertipe int64 menunjukkan data numerik diskrit (bilangan bulat), yang digunakan untuk menunjukkan tahun rilis, jumlah episode, peringkat, dan tingkat popularitas drama.
#
# ---
# 3. Float
# Kolom yang bertipe float64 antara lain:
# * 'duration'
#
# Tipe float64 menunjukkan bahwa kolom ini berisi data numerik kontinu, yaitu total durasi tayang drama (dalam menit).

# %% [markdown]
# ### **Cek Incosistent Values**

# %%
print(df['kdrama_id'].unique())
# Out:
# ['661d4193916c4e71a2c70473ab11e9e8' '5ffcbeaa17114714af1959129984274c'
#  '65075cb9c1a54be4a441cee6f16c9fdf' ... '142a09741fdd4daa878d6ae007201e43'
#  '9170c31a02014b56bb4cec2105086f00' 'c19353bdbc7a43ae98b27db202e7c908']

# %% [markdown]
# Pada kolom 'kdrama_id' ini, tidak ditemukan adanya *incosisten values*. karena data yang ada di kolom 'kdrama_id' bersifat unik.

# %%
print(df['drama_name'].unique())
# Out:
# ['Sing My Crush' 'D.P. Season 2' 'Shadow Detective Season 2' ...
#  'Iron Lady Cha' 'The Family Is Coming' 'Crow Building']

# %% [markdown]
# Pada kolom 'drama_nama' ini, tidak ditemukan adanya *incosistent_value*.

# %%
print(df['director'].unique())
# Out:
# ["['So Joon Moon']" nan "['Han Dong Hwa']" "['Kim Chul Gyu']"
#  "['Kim Chil Bong']" "['Lee Jung Rim', 'Kim Jae Hong']" "['Jung Ji Hyun']"
#  "['Im Hyun Wook', 'Choi Sun Min']" "['Lee Na Jung']" "['Yang Kyung Hee']"
#  "['Kang Hee Ju']" "['Kim Yoon Cheol']" "['Lee Soo Hyun']"
#  "['Lee Jong Pil']" "['Park Sun Jae', 'Kim Hoon Gwang']"
#  "['Kim Eun Kyung', 'Oh Hwan Min']" "['Lee Dong Yoon']"
#  "['Park Joon Sik']" "['Kang Shin Hyo', 'Jo Nam Hyung']"
#  "['Kim Jin Sung']" "['Kang Soo Yeon', 'Lee Woong Hee']" "['Yoo In Shik']"
#  "['Min Chae Yeon']" "['Shim Na Yeon']" "['Kang Ho Jun']"
#  "['Sung Yong Il']" "['Ryu Kwang Hyun']"
#  "['Jang Jung Do', 'Lee Jung Mook']" "['Kim Dae Jin', 'Kim Jung Wook']"
#  "['Oh Jin Suk']" "['Choi Joon Bae', 'Min Jung Ah']"
#  "['Seo Min Jung', 'Lee Tae Gon']" "['Yoo Jong Sun', 'Kim Seung Woo']"
#  "['Kim Hong Seon']" "['Lee Han Joon', 'Kim Seung Ho']" "['Kim Jung Min']"
#  "['Jang Eui Soon']" "['Shin Chang Seok']" "['Choi Young Hoon']"
# ...

# %% [markdown]
# Pada kolom 'director' ini dapat dilihat terdapat *incosistent values* pada nama "Hwang  Gyung Sung" ada *double space*.

# %%
print(df['screenwriter'].unique())
# Out:
# [nan "['Kim Bo Tong']" "['Song Jung Woo', 'Hwang Seol Hun']"
#  "['Kim Yi Young']" "['Oh Hye Seok', 'Jung An']" "['Kim Eun Hee']"
#  "['Ji Ah Nee']" "['Choi Rom']" "['Han Ah Reum', 'Choi Young Rim']"
#  "['Joo Young Ha']" "['Han Woo Joo']" "['Son Mi']" "['Jung Hyun Woo']"
#  "['Jeon Seon Young']" "['Kim Roo Ri']" "['Han Woo Ri']" "['Kang Yoon']"
#  "['Baek So Yeon']" "['Kang Eun Kyung']" "['Seok Bo Bae']"
#  "['Bae Se Young']" "['Im Do Wan']" "['Lee Nam Gyu']" "['Jung Yoo Sun']"
#  "['Jung Yeo Rang']" "['Moon Ji Young']" "['Shin Kyung Il']"
#  "['Ah Kyung']" "['No Yoon Soo']" "['Kim Jin Wook']"
#  "['Choi Jin Young', 'Jung Ho Rak']" "['Kwon Eum Mi']" "['Kang Jae Hyun']"
#  "['Lee Jung Dae']" "['Hyun Ji Min']" "['Kim Eun Sook']"
#  "['Lee Yun Seul']" "['Jung Hyung Soo']" "['Yoo Young Ah']"
#  "['Kim Hoi Joon']" "['Park Hye Young', 'Han Bo Kyung', 'Joo Hyo Jin']"
#  "['Jang Yoon Mi']" "['Kim Ga Eun']" "['Oh Sang Ho']" "['Lee Chun Geum']"
# ...

# %% [markdown]
# Pada kolom 'screenwriter' ini dapat dilihat terdapat *incosistent values* pada nama "Shin So  Young" ada *double space*.

# %%
print(df['country'].unique())
# Out:
# ['South Korea']

# %% [markdown]
# Pada kolom 'country' ini, tidak ditemukan adanya *incosistent value*. Karena hanya mempunyai satu data.

# %%
print(df['type'].unique())
# Out:
# ['Drama']

# %% [markdown]
# Pada kolom 'type' ini, tidak ditemukan adanya *incosistent_value*. Karena hanya mempunyai satu data.

# %%
print(df['start_dt'].unique())
# Out:
# ['Aug  2, 2023' 'Jul 28, 2023' '2023-07-05' ... '2015-01-05' '2015-01-03'
#  '2015']

# %% [markdown]
# Pada kolom 'start_dt' ini dapat dilihat terdapat *incosistent values* dengan formatnya, semuanya memiliki format yang berbeda. Maka hal ini kita bisa tangani dengan menyamakan formatnya menjadi yyyy-mm-dd

# %%
print(df['end_dt'].unique())
# Out:
# ['Aug  2, 2023' 'Jul 28, 2023' '2023-07-26' ... '2015-06-12' '2015-03-15'
#  '2015']

# %% [markdown]
# Pada kolom 'end_dt' ini dapat dilihat terdapat *incosistent values* dengan formatnya, semuanya memiliki format yang berbeda. Maka hal ini kita bisa tangani dengan menyamakan formatnya menjadi yyyy-mm-dd

# %%
print(df['aired_on'].unique())
# Out:
# ['Wednesday' 'Friday' 'Friday, Saturday' 'Monday' 'Monday, Tuesday'
#  'Saturday, Sunday' 'Saturday' 'Wednesday, Thursday' 'Thursday'
#  'Thursday, Friday' nan 'Tuesday, Wednesday'
#  'Monday, Tuesday, Wednesday, Thursday, Friday' 'Monday, Wednesday'
#  'Wednesday, Friday' 'Friday, Saturday, Sunday' 'Tuesday'
#  'Wednesday, Sunday' 'Tuesday, Thursday' 'Thursday, Sunday'
#  'Thursday, Friday, Saturday, Sunday' 'Monday, Tuesday, Wednesday'
#  'Friday, Sunday' 'Sunday' 'Tuesday, Friday'
#  'Monday, Tuesday, Wednesday, Friday, Saturday, Sunday'
#  'Monday, Wednesday, Friday' 'Tuesday, Saturday' 'Wednesday, Saturday'
#  'Monday, Thursday' 'Monday, Sunday' 'Monday, Thursday, Friday'
#  'Monday, Thursday, Saturday'
#  'Monday, Tuesday, Wednesday, Thursday, Sunday' 'Thursday, Saturday'
#  'Tuesday, Wednesday, Thursday' 'Tuesday, Wednesday, Friday'
#  'Sunday, Saturday' 'Tuesday, Saturday, Sunday'
#  'Monday, Thursday, Wednesday, Tuesday' 'Sunday, Tuesday, Thursday'
# ...

# %% [markdown]
# Pada kolom 'aired_on' ini, tidak ditemukan adanya *incosistent value*.

# %%
print(df['org_net'].unique())
# Out:
# [nan 'Netflix' 'Disney+ Hulu' 'Naver TV Cast' 'MBC' 'SBS' 'ENA Genie TV'
#  'jTBC Netflix TVING' 'Netflix TVING tvN' 'MBC Dramanet' 'TVING'
#  'Amazon Prime ENA TVING' 'tvN' 'KBS1' 'KBS2 ViuTV' 'Channel A'
#  'TVING tvN' 'jTBC Netflix' 'ENA TVING' 'SBS ViuTV' 'KBS2'
#  'Hulu TVING tvN' 'KBS2 Viki' 'ENA Genie TV ViuTV' 'Amazon Prime TVING'
#  'ENA Genie TV Viki' 'Netflix tvN' 'jTBC' 'Amazon Prime SBS' 'Netflix SBS'
#  'TV Chosun' 'iQiyi' 'ENA' 'OBS' 'Viki' 'jTBC ViuTV'
#  'DRAMAcube ENA SBS SBS Plus' 'vLive' 'EBS' 'Amazon Prime MBC' 'ENA Viki'
#  'tvN Viki' 'KBS2 Viki ViuTV' 'Daum Kakao TV' 'Amazon Prime jTBC'
#  'ENA jTBC' 'SBS Viki ViuTV' 'Hulu MBC' 'Naver TV Cast Viki vLive'
#  'ENA Netflix' 'KBS2 Netflix' 'Daum Kakao TV Netflix' 'MBC ViuTV'
#  'Naver TV Cast vLive' 'MBC Netflix' 'Disney+' 'OCN' 'MBN Viki'
#  'DRAMAcube' 'LINE TV Viki' 'iQiyi Viki' 'iQiyi tvN' 'TV Chosun Viki'
#  'Naver TV Cast TVING' 'Genie TV' 'Channel A Viki' 'ViuTV'
# ...

# %% [markdown]
# Pada kolom 'org_net' ini, tidak ditemukan adanya *incosistent value*. Karena penulisan kapital dan kapitil sudah sesuai dengan namanya masing-masing.

# %%
print(df['content_rt'].unique())
# Out:
# ['Not Yet Rated' '15+ - Teens 15 or older'
#  '18+ Restricted (violence & profanity)' '13+ - Teens 13 or older'
#  'G - All Ages' 'R - Restricted Screening (nudity & violence)']

# %% [markdown]
# Pada kolom 'content_rt' ini, tidak ditemukan adanya *incosistent values*.

# %%
print(df['synopsis'].unique())
# Out:
# ['Follow the story of acquaintances Ba Ram and Han Tae after an incident occurred during their school years. Now that they are adults, will Ba Ram be able to suppress the feelings for Han Tae that he has harbored for so long?(Source: BLUPDATE2022 Twitter)~~ Adapted from the webtoon "Ttarabaram" (따라바람) by Geom Dung (검둥). '
#  'This unfolding story ensues when military desertion arrest squad members (DP), Jun Ho and Ho Yeol, run across absurdities and unchangeable reality on a regular basis.(Source: Namuwiki; Edited by Krystale Mitaesa at MyDramaList)~~ Adapted from the webtoon "D.P Dog Day" (D.P 개의 날) by Kim Bo Tong (김보통). '
#  "Unfolds the ultimate counterattack of veteran homicide detective Kim Taek Rok, who has returned to investigate the secret mastermind behind the blackmailer 'Friend'.(Source: Sports Chosun; edited by Krystale Mitaesa at MyDramaList) "
#  ...
# ...

# %% [markdown]
# Pada kolom 'synopsis' ini, tidak ditemukan adanya *incosistent values*.

# %% [markdown]
# ### **Cek Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#               Null Ratio in %
# kdrama_id            0.000000
# drama_name           0.000000
# year                 0.000000
# director            40.867580
# screenwriter        45.262557
# country              0.000000
# type                 0.000000
# tot_eps              0.000000
# duration             1.369863
# start_dt             0.000000
# end_dt               0.000000
# aired_on            13.242009
# org_net             23.287671
# content_rt           0.000000
# synopsis             9.589041
# rank                 0.000000
# pop                  0.000000

# %% [markdown]
# Kolom-kolom yang membutuhkan perhatian lebih karena memiliki *missing values* adalah:
# * 'screenwriter' = 45,26%
# * 'director' = 40,87%
# * 'duration' = 1,37%
# * 'org_net' = 23,29%
# * 'aired_on' = 13,24%
# * 'synopsis' = 9,59%
#
# ---
# Kolom-kolom yang tidak memiliki masalah *missing values* (0%) antara lain:
# * 'kdrama_id'
# * 'drama_name'
# * 'year'
# * 'country'
# * 'type'
# * 'tot_eps'
# * 'start_dt'
# * 'end_dt'
# * 'content_rt'
# * 'rank'
# * 'pop'
#
# Kolom-kolom tersebut lengkap sepenuhnya dan sangat andal untuk digunakan dalam analisis statistik dan visualisasi.

# %% [markdown]
# ### **Cek Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [kdrama_id, drama_name, year, director, screenwriter, country, type, tot_eps, duration, start_dt, end_dt, aired_on, org_net, content_rt, synopsis, rank, pop]
# Index: []

# %% [markdown]
# Dapat dilihat bahwa dataset ini tidak memiliki *duplicated values*, maka tidak ada yang perlu ditangani. Ini menunjukkan kualitas data yang baik dalam hal tidak adanya duplikasi.

# %% [markdown]
# ### **Cek Outliers**

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom     Persentase Outliers
# year                 0.000000
# tot_eps             13.641553
# duration             0.057078
# rank                 0.000000
# pop                 18.892694

# %% [markdown]
# Kolom 'pop' menunjukkan persentase outlier tertinggi, sekitar 18,89%, yang menandakan adanya sejumlah nilai popularitas yang sangat berbeda dibandingkan dengan mayoritas data. Hal ini bisa menunjukkan adanya beberapa judul yang memiliki tingkat popularitas sangat tinggi (atau sangat rendah) sehingga perlu diselidiki lebih lanjut apakah nilai tersebut valid atau merupakan anomali.
#
# ---
#
# Kolom 'tot_eps' juga menunjukkan persentase outliers yang cukup signifikan, yaitu sekitar 13,64%. Hal ini mengindikasikan adanya beberapa drama dengan jumlah episode yang jauh lebih banyak atau lebih sedikit daripada pola umum dataset. Diperlukan pengecekan untuk memastikan apakah ini merupakan format khusus (seperti drama panjang atau mini series) atau karena data yang tidak konsisten.
#
# ---
#
# Kolom 'duration' memiliki persentase outlier yang sangat kecil, hanya sekitar 0,06%, sehingga secara umum, durasi episode cenderung konsisten dan stabil. Outlier yang ada kemungkinan hanya merupakan kasus-kasus yang bersifat khusus.
#
# ---
#
# Sementara, kolom 'year' dan 'rank' tidak memiliki outliers (0%), yang menunjukkan distribusi data pada kedua kolom ini cukup terkontrol dan tidak terdapat nilai yang menyimpang secara ekstrem.

# %% [markdown]
# ## V **Exploratory Data Analysis** V

# %% [markdown]
# ### **Comparison/Perbandingan**

# %%
tahun_drama = df['year'].value_counts()

plt.figure(figsize=(10,6))
sns.barplot(x=tahun_drama.index,y=tahun_drama.values,hue=tahun_drama.index,palette='twilight',legend=False)
plt.title('Jumlah Drama Berdasarkan Tahun Rilis')
plt.xlabel('Tahun Rilis')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, terdapat pola peningkatan produksi yang stabil dari tahun 2015 hingga mencapai puncaknya pada tahun 2019. Pada tahun 2020, terlihat sedikit penurunan dalam jumlah produksi, yang mungkin dipicu oleh faktor eksternal seperti gangguan dalam proses produksi(pandemi). Selanjutnya, industri menunjukkan pemulihan yang signifikan dengan lonjakan produksi pada tahun 2021, yang menjadi titik tertinggi dalam periode tersebut. Namun, dari tahun 2022 hingga 2023, kembali muncul tren penurunan, di mana tahun 2023 mencatat angka terendah dalam beberapa tahun terakhir, yang mungkin disebabkan oleh data yang belum sepenuhnya tersedia atau adanya penurunan produksi yang nyata.

# %% [markdown]
# ### **Composition/Komposisi**

# %%
rate_eps = df.groupby('content_rt')['tot_eps'].sum().sort_values(ascending=False)
rate_eps_top3 = rate_eps.head(3)

plt.figure(figsize=(10, 8))
rate_eps_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Pastel2.colors)
plt.title('Proporsi Total Episode Berdasarkan Content Rating (Top 3)')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Berdasarkan visualisasi tersebut, kategori 15+ (Teens 15 or older) mendominasi total episode dengan proporsi sekitar 75,1%, menunjukkan bahwa mayoritas produksi drama ditujukan untuk remaja ke atas sebagai target pasar utama. Sementara itu, kategori Not Yet Rated menyumbang sekitar 20%, dan kategori 13+ hanya sekitar 4,8%, sehingga kontribusinya relatif kecil dibandingkan kategori 15+. Hal ini mengindikasikan bahwa industri drama lebih banyak memproduksi konten dengan segmentasi usia 15 tahun ke atas dibandingkan rating lainnya.

# %% [markdown]
# ### **Distribution/Distribusi**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['duration'], bins=20, kde=True)
plt.title('Distribusi Durasi Drama')
plt.xlabel('durasi')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berdasarkan histogram distribusi durasi drama, terlihat bahwa mayoritas drama memiliki durasi yang terkonsentrasi pada rentang tertentu, namun distribusinya tidak simetris dan cenderung right-skewed. Hal ini ditunjukkan dengan adanya beberapa drama berdurasi sangat panjang yang membentuk ekor panjang di sisi kanan grafik. Distribusi juga menunjukkan adanya variasi durasi yang cukup beragam antar drama.

# %% [markdown]
# ### **Relationship/Hubungan**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['year', 'tot_eps', 'duration', 'rank', 'pop']].corr(),
            annot=True,
            cmap='YlGnBu',
            fmt='.2f')
plt.title('Korelasi Antar Kolom Numerik')
plt.show()

# %% [markdown]
# Berdasarkan heatmap, terlihat bahwa hubungan paling kuat terdapat antara rank dan pop dengan korelasi positif sebesar 0.77, yang menunjukkan adanya hubungan yang sangat kuat antara peringkat dan tingkat popularitas. Selain itu, terdapat korelasi negatif cukup kuat antara duration dan rank (-0.53) serta duration dan pop (-0.49), yang mengindikasikan bahwa durasi yang lebih panjang cenderung berkaitan dengan perubahan pada peringkat dan popularitas.
#
# Sementara itu, variabel lain seperti year, tot_eps, dan kombinasi antar keduanya menunjukkan korelasi yang relatif lemah (mendekati 0), sehingga tidak terdapat hubungan linear yang signifikan antar variabel tersebut. Secara keseluruhan, variabel yang paling berpengaruh dalam hubungan numerik pada dataset ini adalah rank, pop, dan duration, sedangkan tahun rilis dan total episode tidak menunjukkan hubungan yang kuat dengan variabel lainnya.

# %% [markdown]
# # 3.**Data Preparation**

# %% [markdown]
# ## V **Penanganan Tipe Data** V

# %% [markdown]
# ### **Pengecekan Tipe Data**

# %%
df.dtypes
# Out:
# kdrama_id        object
# drama_name       object
# year              int64
# director         object
# screenwriter     object
# country          object
# type             object
# tot_eps           int64
# duration        float64
# start_dt         object
# end_dt           object
# aired_on         object
# org_net          object
# content_rt       object
# synopsis         object
# rank              int64
# pop               int64
# dtype: object

# %% [markdown]
# Bisa dilihat kolom 'duration' yang tipe datanya float64. Kolom ini harus dirubah ke int64 karena melihat semua nilai di kolom ini angka dibelakang koma itu 0 yang berarti itu tidak berpengaruh jika dirubah. Dan juga melihat dataset ini dikaggle kolom ini bukan desimal. Untuk kolom 'start_dt' dan 'end_dt' sebenarnya harus dirubah juga menjadi datetime64[ns] namun saya akan merubahnya di bagian penanganan *incosistent values*. Sedangkan untuk kolom lainnya sudah cocok dengan tipe data nya masing-masing.

# %% [markdown]
# ### **Perubahan Tipe Data**

# %%
df['duration'] = df['duration'].astype('Int64')

# %% [markdown]
# ### **Pengecekan Ulang**

# %%
df.dtypes
# Out:
# kdrama_id       object
# drama_name      object
# year             int64
# director        object
# screenwriter    object
# country         object
# type            object
# tot_eps          int64
# duration         Int64
# start_dt        object
# end_dt          object
# aired_on        object
# org_net         object
# content_rt      object
# synopsis        object
# rank             int64
# pop              int64
# dtype: object

# %% [markdown]
# Setelah ditangani kolom 'duration' yang sebelumnya bertipe float64 menjadi bertipe int64.

# %% [markdown]
# ## V **Data Cleaning** V

# %% [markdown]
# ### v **Penanganan Incosistent Values** v

# %% [markdown]
# #### **Pengecekan Incosistent Values**

# %%
print(df['director'].unique())
# Out:
# ["['So Joon Moon']" nan "['Han Dong Hwa']" "['Kim Chul Gyu']"
#  "['Kim Chil Bong']" "['Lee Jung Rim', 'Kim Jae Hong']" "['Jung Ji Hyun']"
#  "['Im Hyun Wook', 'Choi Sun Min']" "['Lee Na Jung']" "['Yang Kyung Hee']"
#  "['Kang Hee Ju']" "['Kim Yoon Cheol']" "['Lee Soo Hyun']"
#  "['Lee Jong Pil']" "['Park Sun Jae', 'Kim Hoon Gwang']"
#  "['Kim Eun Kyung', 'Oh Hwan Min']" "['Lee Dong Yoon']"
#  "['Park Joon Sik']" "['Kang Shin Hyo', 'Jo Nam Hyung']"
#  "['Kim Jin Sung']" "['Kang Soo Yeon', 'Lee Woong Hee']" "['Yoo In Shik']"
#  "['Min Chae Yeon']" "['Shim Na Yeon']" "['Kang Ho Jun']"
#  "['Sung Yong Il']" "['Ryu Kwang Hyun']"
#  "['Jang Jung Do', 'Lee Jung Mook']" "['Kim Dae Jin', 'Kim Jung Wook']"
#  "['Oh Jin Suk']" "['Choi Joon Bae', 'Min Jung Ah']"
#  "['Seo Min Jung', 'Lee Tae Gon']" "['Yoo Jong Sun', 'Kim Seung Woo']"
#  "['Kim Hong Seon']" "['Lee Han Joon', 'Kim Seung Ho']" "['Kim Jung Min']"
#  "['Jang Eui Soon']" "['Shin Chang Seok']" "['Choi Young Hoon']"
# ...

# %% [markdown]
# Dikolom 'director' ini ditemukan ada 1 nilai yang tidak konsisten karena *double space*. Dengan begitu kolom ini harus ditangani.

# %%
print(df['screenwriter'].unique())
# Out:
# [nan "['Kim Bo Tong']" "['Song Jung Woo', 'Hwang Seol Hun']"
#  "['Kim Yi Young']" "['Oh Hye Seok', 'Jung An']" "['Kim Eun Hee']"
#  "['Ji Ah Nee']" "['Choi Rom']" "['Han Ah Reum', 'Choi Young Rim']"
#  "['Joo Young Ha']" "['Han Woo Joo']" "['Son Mi']" "['Jung Hyun Woo']"
#  "['Jeon Seon Young']" "['Kim Roo Ri']" "['Han Woo Ri']" "['Kang Yoon']"
#  "['Baek So Yeon']" "['Kang Eun Kyung']" "['Seok Bo Bae']"
#  "['Bae Se Young']" "['Im Do Wan']" "['Lee Nam Gyu']" "['Jung Yoo Sun']"
#  "['Jung Yeo Rang']" "['Moon Ji Young']" "['Shin Kyung Il']"
#  "['Ah Kyung']" "['No Yoon Soo']" "['Kim Jin Wook']"
#  "['Choi Jin Young', 'Jung Ho Rak']" "['Kwon Eum Mi']" "['Kang Jae Hyun']"
#  "['Lee Jung Dae']" "['Hyun Ji Min']" "['Kim Eun Sook']"
#  "['Lee Yun Seul']" "['Jung Hyung Soo']" "['Yoo Young Ah']"
#  "['Kim Hoi Joon']" "['Park Hye Young', 'Han Bo Kyung', 'Joo Hyo Jin']"
#  "['Jang Yoon Mi']" "['Kim Ga Eun']" "['Oh Sang Ho']" "['Lee Chun Geum']"
# ...

# %% [markdown]
# Dikolom 'screenwriter' ini juga ditemukan ada 1 nilai yang tidak konsisten karena *double space*. Dengan begitu kolom ini harus ditangani.

# %%
print(df['start_dt'].unique())
print('                                                                         ')
print('-------------------------------------------------------------------------')
print('                                                                         ')
print(df['end_dt'].unique())
# Out:
# ['Aug  2, 2023' 'Jul 28, 2023' '2023-07-05' ... '2015-01-05' '2015-01-03'
#  '2015']
#
# -------------------------------------------------------------------------
#
# ['Aug  2, 2023' 'Jul 28, 2023' '2023-07-26' ... '2015-06-12' '2015-03-15'
#  '2015']

# %% [markdown]
# Pada kedua kolom ini yaitu 'start_dt' dan 'end_dt' merupakan *incosistent values* karena dikedua kolom ini format penulisan tanggalnya berbeda-beda dan juga ditemuka nilai yang merupakan *range* sepeti "May, 2021 - Jul, 2021" Dengan begitu kedua kolom ini harus ditangani.

# %% [markdown]
# #### **Perbaikan Incosistent Values**

# %%
df["director"] = (
    df["director"]
    .str.strip()
    .str.replace(r"\s+", " ", regex=True)
)

# %%
df["screenwriter"] = (
    df["screenwriter"]
    .str.strip()
    .str.replace(r"\s+", " ", regex=True)
)

# %% [markdown]
# kedua kode diatas untuk memperbaiki nilai *doublespace* yang ditemukan di kolom 'director' dan 'screenwriter'.

# %%
df['start_dt'] = df['start_dt'].replace({
    'May, 2021 - Jul, 2021': '2021-05-01',
    'Aug 30, 2017 - 2017': '2017-08-30',
    'Aug, 2017 - 2017': '2017-08-01',
    'Jan 15, 2017 - 2017': '2017-01-15',
    'Aug, 2016 - Oct, 2016': '2016-08-01'
})

df['start_dt'] = pd.to_datetime(df['start_dt'], format='mixed')
df["start_dt"].head(5)
# Out:
# 0   2023-08-02
# 1   2023-07-28
# 2   2023-07-05
# 3   2023-06-30
# 4   2023-06-30
# Name: start_dt, dtype: datetime64[ns]

# %% [markdown]
# sebelum kita mengubah semua nilai yang ada dikolom 'start_dt' ini terlebih dahulu kita mengubah nilai yang merupakan *range* menjadi format tanggal yang sesuai, lalu setelah itu kita mengubah tipe datanya menjadi datetime agar kolom ini konsisten nilai-nilainya. Alasan mengubah nilai yang tidak memiliki nilai yang tidak memiliki tanggal seperti "Aug, 2017" menjadi "2017-08-01" karena pada umumnya jika tidak diketahui tanggal pastinya akan berubah menjadi tanggal 01.

# %%
df['end_dt'] = df['end_dt'].replace({
    'May, 2021 - Jul, 2021': '2021-07-01',
    'Aug 30, 2017 - 2017': '2017-12-31',
    'Aug, 2017 - 2017': '2017-12-31',
    'Jan 15, 2017 - 2017': '2017-12-31',
    'Aug, 2016 - Oct, 2016': '2016-10-01'
})

df['end_dt'] = pd.to_datetime(df['end_dt'], format='mixed')
df["end_dt"].head(5)
# Out:
# 0   2023-08-02
# 1   2023-07-28
# 2   2023-07-26
# 3   2023-07-14
# 4   2023-06-30
# Name: end_dt, dtype: datetime64[ns]

# %% [markdown]
# sebelum kita mengubah semua nilai yang ada dikolom 'start_dt' ini terlebih dahulu kita mengubah nilai yang merupakan *range* menjadi format tanggal yang sesuai, lalu setelah itu kita mengubah tipe datanya menjadi datetime agar kolom ini konsisten nilai-nilainya. Alasan mengubah nilai yang tidak memiliki nilai yang tidak memiliki tanggal dan bulan seperti "2017" menjadi "2017-12-31" karena pada umumnya jika tidak diketahui tanggal dan bulan pastinya akan berubah menjadi bulan 12 dan tanggal 1.

# %% [markdown]
# #### **Pengecekan Ulang**

# %%
print(df['director'].unique())
# Out:
# ["['So Joon Moon']" nan "['Han Dong Hwa']" "['Kim Chul Gyu']"
#  "['Kim Chil Bong']" "['Lee Jung Rim', 'Kim Jae Hong']" "['Jung Ji Hyun']"
#  "['Im Hyun Wook', 'Choi Sun Min']" "['Lee Na Jung']" "['Yang Kyung Hee']"
#  "['Kang Hee Ju']" "['Kim Yoon Cheol']" "['Lee Soo Hyun']"
#  "['Lee Jong Pil']" "['Park Sun Jae', 'Kim Hoon Gwang']"
#  "['Kim Eun Kyung', 'Oh Hwan Min']" "['Lee Dong Yoon']"
#  "['Park Joon Sik']" "['Kang Shin Hyo', 'Jo Nam Hyung']"
#  "['Kim Jin Sung']" "['Kang Soo Yeon', 'Lee Woong Hee']" "['Yoo In Shik']"
#  "['Min Chae Yeon']" "['Shim Na Yeon']" "['Kang Ho Jun']"
#  "['Sung Yong Il']" "['Ryu Kwang Hyun']"
#  "['Jang Jung Do', 'Lee Jung Mook']" "['Kim Dae Jin', 'Kim Jung Wook']"
#  "['Oh Jin Suk']" "['Choi Joon Bae', 'Min Jung Ah']"
#  "['Seo Min Jung', 'Lee Tae Gon']" "['Yoo Jong Sun', 'Kim Seung Woo']"
#  "['Kim Hong Seon']" "['Lee Han Joon', 'Kim Seung Ho']" "['Kim Jung Min']"
#  "['Jang Eui Soon']" "['Shin Chang Seok']" "['Choi Young Hoon']"
# ...

# %% [markdown]
# Nilai 'Hwang Gyung Sung' yang sebelumnya ada *double space* setelah diperbaiki tidak memiliki *double space* lagi.

# %%
print(df['screenwriter'].unique())
# Out:
# [nan "['Kim Bo Tong']" "['Song Jung Woo', 'Hwang Seol Hun']"
#  "['Kim Yi Young']" "['Oh Hye Seok', 'Jung An']" "['Kim Eun Hee']"
#  "['Ji Ah Nee']" "['Choi Rom']" "['Han Ah Reum', 'Choi Young Rim']"
#  "['Joo Young Ha']" "['Han Woo Joo']" "['Son Mi']" "['Jung Hyun Woo']"
#  "['Jeon Seon Young']" "['Kim Roo Ri']" "['Han Woo Ri']" "['Kang Yoon']"
#  "['Baek So Yeon']" "['Kang Eun Kyung']" "['Seok Bo Bae']"
#  "['Bae Se Young']" "['Im Do Wan']" "['Lee Nam Gyu']" "['Jung Yoo Sun']"
#  "['Jung Yeo Rang']" "['Moon Ji Young']" "['Shin Kyung Il']"
#  "['Ah Kyung']" "['No Yoon Soo']" "['Kim Jin Wook']"
#  "['Choi Jin Young', 'Jung Ho Rak']" "['Kwon Eum Mi']" "['Kang Jae Hyun']"
#  "['Lee Jung Dae']" "['Hyun Ji Min']" "['Kim Eun Sook']"
#  "['Lee Yun Seul']" "['Jung Hyung Soo']" "['Yoo Young Ah']"
#  "['Kim Hoi Joon']" "['Park Hye Young', 'Han Bo Kyung', 'Joo Hyo Jin']"
#  "['Jang Yoon Mi']" "['Kim Ga Eun']" "['Oh Sang Ho']" "['Lee Chun Geum']"
# ...

# %% [markdown]
# Nilai 'Shin So Young' yang sebelumnya ada *double space* setelah diperbaiki tidak memiliki *double space* lagi.

# %%
print(df['start_dt'].unique())
# Out:
# <DatetimeArray>
# ['2023-08-02 00:00:00', '2023-07-28 00:00:00', '2023-07-05 00:00:00',
#  '2023-06-30 00:00:00', '2023-06-28 00:00:00', '2023-06-23 00:00:00',
#  '2023-06-19 00:00:00', '2023-06-17 00:00:00', '2023-06-09 00:00:00',
#  '2023-06-07 00:00:00',
#  ...
#  '2015-01-28 00:00:00', '2015-01-27 00:00:00', '2015-01-21 00:00:00',
#  '2015-01-19 00:00:00', '2015-01-17 00:00:00', '2015-01-09 00:00:00',
#  '2015-01-07 00:00:00', '2015-01-05 00:00:00', '2015-01-03 00:00:00',
#  '2015-01-01 00:00:00']
# Length: 1246, dtype: datetime64[ns]

# %%
print(df['end_dt'].unique())
# Out:
# <DatetimeArray>
# ['2023-08-02 00:00:00', '2023-07-28 00:00:00', '2023-07-26 00:00:00',
#  '2023-07-14 00:00:00', '2023-06-30 00:00:00', '2023-07-19 00:00:00',
#  '2023-07-29 00:00:00', '2023-08-07 00:00:00', '2023-07-11 00:00:00',
#  '2023-08-06 00:00:00',
#  ...
#  '2015-03-12 00:00:00', '2015-03-05 00:00:00', '2015-03-26 00:00:00',
#  '2015-04-12 00:00:00', '2015-03-27 00:00:00', '2015-03-07 00:00:00',
#  '2015-06-22 00:00:00', '2015-06-12 00:00:00', '2015-03-15 00:00:00',
#  '2015-01-01 00:00:00']
# Length: 1266, dtype: datetime64[ns]

# %% [markdown]
# Setelah ditangani kedua kolom diatas sudah berubah kolom yang konsisten dengan format tanggal yyyy-mm-dd dan tipe data nya berubah menjadi datetime64[ns]

# %% [markdown]
# ### v **Penanganan Missing Values** v

# %% [markdown]
# #### **Pengecekan Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#               Null Ratio in %
# kdrama_id            0.000000
# drama_name           0.000000
# year                 0.000000
# director            40.867580
# screenwriter        45.262557
# country              0.000000
# type                 0.000000
# tot_eps              0.000000
# duration             1.369863
# start_dt             0.000000
# end_dt               0.000000
# aired_on            13.242009
# org_net             23.287671
# content_rt           0.000000
# synopsis             9.589041
# rank                 0.000000
# pop                  0.000000

# %% [markdown]
# Kolom-kolom berikut memiliki *missing values*:
# * 'screenwriter' = 45,26%
# * 'director' = 40,87%
# * 'duration' = 1,37%
# * 'org_net' = 23,29%
# * 'aired_on' = 13,24%
# * 'synopsis' = 9,59%
#
# Kolom-kolom tersebut harus ditangani, sedangkan kolom lainnya tidak memilki *missing values*.

# %% [markdown]
# #### **Perbaikan Missing Values**

# %% [markdown]
# ##### **Mengisi Dengan Unknown**

# %%
df['director'] = df['director'].fillna('unknown')

# %%
df['screenwriter'] = df['screenwriter'].fillna('unknown')

# %%
df['aired_on'] = df['aired_on'].fillna('unknown')

# %%
df['org_net'] = df['org_net'].fillna('unknown')

# %%
df['synopsis'] = df['synopsis'].fillna('unknown')

# %% [markdown]
# Alasan saya mengisi kolom-kolom ini dengan "unknwon" karena jika saya menggunakan modus dia akan mengisi dengan nilai yang paling sering muncul dimana itu tidak akurat.

# %% [markdown]
# ##### **Mengisi Dengan Imputasi**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['duration'], bins=20, kde=True)
plt.title('Pengecekan buat Missing Value')
plt.xlabel('durasi')
plt.ylabel('Frekuensi')
plt.show()

# %%
df['duration'] = df['duration'].fillna(df['duration'].dropna().median())

# %% [markdown]
# Alasan saya menggunakan median karena kolom ini jika dilihat visualisasi histogramnya yaitu *skewed right* (tidak normal) jadi saya menggunkan median daripada mean.

# %% [markdown]
# #### **Pengecekan Ulang**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#               Null Ratio in %
# kdrama_id                 0.0
# drama_name                0.0
# year                      0.0
# director                  0.0
# screenwriter              0.0
# country                   0.0
# type                      0.0
# tot_eps                   0.0
# duration                  0.0
# start_dt                  0.0
# end_dt                    0.0
# aired_on                  0.0
# org_net                   0.0
# content_rt                0.0
# synopsis                  0.0
# rank                      0.0
# pop                       0.0

# %% [markdown]
# Setelah saya melakukan penanganan bisa dilihat sekarang tidak ada lagi *missing values* di kolom 'director', 'screenwriter', 'duration', 'aired_on','org_net' dan 'synopsis'.

# %% [markdown]
# ### v **Penanganan Duplicated Value** v

# %% [markdown]
# #### **Pengecekan Duplicated Value**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [kdrama_id, drama_name, year, director, screenwriter, country, type, tot_eps, duration, start_dt, end_dt, aired_on, org_net, content_rt, synopsis, rank, pop]
# Index: []

# %% [markdown]
# Dataset ini tidak memiliki baris yang duplikat jadi tidak ada yang perlu ditangani.

# %% [markdown]
# ### v **Penanganan Outliers** v

# %% [markdown]
# #### **Pengecekan Outliers**

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom     Persentase Outliers
# year                 0.000000
# tot_eps             13.641553
# duration             0.057078
# rank                 0.000000
# pop                 18.892694

# %% [markdown]
# Dari hasil diatas kolom-kolom yang memiliki "outliars":
# - 'tot_eps' : 13%
# - 'duration' : 0,05%
# - 'pop' : 18%
#
# ---
#
# Alasan mengapa kolom 'duration'(detik) harus ditangani karena kolom ini yang memiliki beberapa nilai yang menurut saya tidak normal, salah satu contohnya yaitu drama yang berjudul "Convenience Store Junkies" yang memiliki nilai "60" yang berarti setiap episode nya hanya berdurasi 1 menit, sedangkan setelah saya melakukan *searching* drama ini harusnya memiliki 10 - 20 mnt pe-episodenya.
#
# sedangkan, kolom-kolom berikut tidak perlu saya tangani:
# - 'tot_eps' : Karena dataset merupakan campuran dari beberapa tipe drama yaitu "series", "webseries", "drama harian", dll. Jadi menurut saya *outliers* disini masih normal karena tipe yang drama harian memang bisa saja mencapai ratusan episode.
# - 'pop' : Karena nilai "99999" disini bukan *outliers*, menurut saya mengapa itu bisa ada karena nilai tersebut sebagai "pengganti" dari drama yang tidak diketahui popularitasnya (sama halnya dengan rank).

# %% [markdown]
# #### **Perbaikan Outlier**

# %%
columns_to_impute = ["duration"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# #### **Pengecekan Ulang**

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom     Persentase Outliers
# year                 0.000000
# tot_eps             13.641553
# duration             0.000000
# rank                 0.000000
# pop                 18.892694

# %% [markdown]
# Setelah kita tangani *outliers* yang berada di kolom 'duration', bisa dilihat sekarang *outliers* dikolom tersebut sudah 0%.

# %% [markdown]
# ## V **Construct Data** V

# %% [markdown]
# ### **Code**

# %%
df['total_days_aired'] = (df['end_dt'] - df['start_dt']).dt.days.astype(int)

# %% [markdown]
# Fungsi dari kolom tambahan ini untuk menampilkan total berapa hari sebuah drama tayang dari episode pertama hingga akhir. Sebenarnya kolom ini tidak terlalu relevan dengan studi kasus saya tapi kolom ini bisa jadi faktor yang memengaruhi popularitas suatu drama. lalu, kolom ini bertipe data integer karena numerik dan juga tidak mungkin hari tipe datanya float.

# %% [markdown]
# ### **Pengecekan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1752 entries, 0 to 1751
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   kdrama_id         1752 non-null   object
#  1   drama_name        1752 non-null   object
#  2   year              1752 non-null   int64
#  3   director          1752 non-null   object
#  4   screenwriter      1752 non-null   object
#  5   country           1752 non-null   object
#  6   type              1752 non-null   object
#  7   tot_eps           1752 non-null   int64
#  8   duration          1752 non-null   Int64
#  9   start_dt          1752 non-null   datetime64[ns]
#  10  end_dt            1752 non-null   datetime64[ns]
#  11  aired_on          1752 non-null   object
#  12  org_net           1752 non-null   object
#  13  content_rt        1752 non-null   object
#  14  synopsis          1752 non-null   object
#  15  rank              1752 non-null   int64
# ...

# %%
df
# Out:
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# 1748  1e7f7f2fa45d4240b8bb585ca13040f0        Enchanting Neighbor  2015
# 1749  142a09741fdd4daa878d6ae007201e43              Iron Lady Cha  2015
# 1750  9170c31a02014b56bb4cec2105086f00       The Family Is Coming  2015
# 1751  c19353bdbc7a43ae98b27db202e7c908              Crow Building  2015
#
#                                director                         screenwriter  \
# ...

# %% [markdown]
# Setelah saya menambahkan kolom 'total_days_aired', dan bisa dilihat kolom tersebut sudah muncul.

# %% [markdown]
# ## V **Data Reduction** V

# %%
df = df.drop('kdrama_id', axis=1)

# %% [markdown]
# Kolom ini saya hapus karena dataset ini tidak ada relasi dengan dataset lain.

# %%
df = df.drop('country', axis=1)

# %% [markdown]
# Kolom ini saya hapus karena semua nilainya berisi sama yaitu "South Korea", Dan juga dari dataset ini yang memang berisikan DraKor yang dimana sudah pasti dari Korea.

# %%
df = df.drop('type', axis=1)

# %% [markdown]
# Kolom ini saya hapus karena semua nilainya berisi sama yaitu "Drama", Dan juga dari dataset ini yang memang berisikan DraKor yang dimana sudah pasti bertipe Drama.

# %%
df = df.drop('start_dt', axis=1)

# %%
df = df.drop('end_dt', axis=1)

# %% [markdown]
# Kedua kolom diatas saya hapus karena tidak lagi dibutuhkan karena kalau jika ingin melihat tahun sudah ada di kolom 'year' dan juga karena kolom 'total_days_aired' saya buat jadi 2 kolom ini sudah tidak ada fungsi nya lagi.

# %%
df = df.drop('aired_on', axis=1)

# %% [markdown]
# Kolom diatas saya hapus karena tidak relevan dengan studi kasus saya.

# %%
df = df.drop('synopsis', axis=1)

# %% [markdown]
# Kolom diatas saya hapus karena tidak relevan dengan studi kasus saya.

# %% [markdown]
# # 4.**Visualization**

# %% [markdown]
# ## V **Bar Chart** V

# %%
df['director_clean'] = df['director'].str.findall(r"'(.*?)'")
df_exploded = df.explode('director_clean')

ranksutradara = df_exploded.groupby('director_clean')['rank'].mean().sort_values(ascending=True).head(10)

plt.figure(figsize=(10, 6)) # Ukuran
sns.barplot(x=ranksutradara.index,y=ranksutradara.values,hue=ranksutradara.index,palette='twilight',legend=False)
plt.xlabel('Nama Sutradara') # keterangan X label
plt.ylabel('Rata-rata Rank') # keterangan y label
plt.title('Top 10 Sutradara dengan Rata-rata Rank Terbaik') # Judul
plt.xticks(rotation=45, ha='right') # rotasi teks
plt.tight_layout()
plt.show()

# %% [markdown]
# Kolom director di dataset masih berbentuk string list seperti "['Shin Won Ho', 'Park In Je']". Kalau langsung di groupby tanpa diolah dulu, Python akan membacanya sebagai satu kesatuan teks bukan sebagai dua nama sutradara yang berbeda sehingga analisis per sutradara tidak bisa dilakukan.
#
# str.findall(r"'(.*?)'") berfungsi mengekstrak setiap nama yang diapit tanda kutip menjadi list Python yang sesungguhnya, sedangkan explode() memecah list tersebut sehingga setiap sutradara mendapat baris sendiri di dataframe. Hasilnya setiap sutradara bisa dihitung dan dianalisis secara individual, termasuk sutradara yang berkolaborasi dalam satu drama.

# %% [markdown]
# Kenapa menggunkan mean untuk kolom rank, karena tujuannya adalah melihat konsistensi performa sutradara, bukan total akumulasi. Kalau menggunakan sum, sutradara yang punya banyak drama otomatis punya total rank besar meskipun kualitas dramanya biasa saja. Dengan mean, semua sutradara dibandingkan secara adil berdasarkan rata-rata kualitas dramanya sutradara yang hanya punya 2 drama tapi keduanya bagus tetap bisa bersaing dengan sutradara yang punya 10 drama.

# %% [markdown]
#  ### **Insight**
#
#  Berdasarkan bar chart diatas, sutradara yang bernama Shin Won Ho menjadi posisi teratas karena memilki rata-rata rank dengan nilai dibawah 50. Disusul oleh Park In Je, Lee Dan, dan Kim Tae Yoon yang juga mencatatkan rata-rata rank di bawah 100. Dari sini kita bisa lihat ada kesenjangan yang cukup signifikan antara sutradara Shin Won Ho dengan sutradara lainnya, yang berarti sutradara Shin Won Ho konsisten menghasilkan drama dengan rata-rata rank yang jauh lebih tinggi dibandung sutradara lain.

# %% [markdown]
# ### **Action**
#
# Mengingat bahwa Shin Won Ho terbukti paling konsisten dalam menghasilkan drama dengan rank palin baik, para platform atau produsen konten sebaiknya memprioritaskan kerja sama dengan sutradara ini untuk proyek drama mendatang. Selain itu, sutradara seperti Park In Je, Lee Dan,dan Kim Tae Yoon juga pantas dipertimbangkan sebagai alternatif karena rata-rata peringkat mereka masih di bawah 100, yang tergolong kategori sangat baik. Mengenai sutradara yang memiliki rata-rata peringkat di atas 150, perlu dilakukan analisis lebih lanjut untuk menentukan apakah performa yang kurang baik ini disebabkan oleh faktor konten, platform penayangan, atau faktor lainnya sebelum mengambil keputusan untuk berkolaborasi.

# %% [markdown]
# ## V **Pie Chart** V

# %%
plt.figure(figsize=(17, 10)) # ukuran
plt.pie(df['content_rt'].value_counts(), labels=df['content_rt'].value_counts().index, autopct='%1.1f%%', colors=['#003049', '#D62828', '#F77F00', '#FCBF49', '#EAE2B7', '#2A9D8F']) # colors (warna)
plt.title('Proporsi Drama Berdasarkan Rating Konten') # Judul
plt.show()

# %% [markdown]
#  ### **Insight**
#
# Dari pie chart diatas, mayoritas drama Korea didominasi oleh rating 15+ (54,5%), yang berarti lebih dari separuh drama Korea diproduksi untuk segmen remaja hingga dewasa. Posisi kedua ditempati oleh drama Not Yet Rated (30,9%), yang jumlahnya cukup besar dan mengindikasikan banyak drama yang belum atau tidak memiliki klasifikasi rating resmi. Drama dengan rating 13+ hanya 8%, sementara rating 18+, G, dan R masing-masing sangat kecil di bawah 4% bahkan hampir tidak signifikan untuk rating R di angka 0,1%.

# %% [markdown]
# ### **Action**
#
# Dengan dominasi rating 15+ yang mencapai lebih dari separuh total drama, platform dan produsen konten sebaiknya memprioritaskan strategi promosi yang menyasar segmen remaja hingga dewasa muda karena segmen inilah yang paling banyak dilayani oleh industri drama Korea. Besarnya proporsi drama Not Yet Rated (30,9%) juga perlu mendapat perhatian drama-drama ini sebaiknya segera diklasifikasikan agar memudahkan proses rekomendasi konten kepada penonton yang tepat. Sementara itu, drama dengan rating 18+ meskipun kecil proporsinya tetap memiliki segmen penonton tersendiri yang bisa dijadikan peluang konten dengan segmen penonton khusus yang bisa didekati melalui strategi pemasaran yang lebih tertarget.

# %% [markdown]
# ## V **Histogram** V

# %%
df_filtered = df[df['pop'] != 99999] # filter sentinel value

plt.figure(figsize=(8, 5))
sns.histplot(df_filtered['pop'], bins=20, kde=True, color='pink', edgecolor='purple')
plt.title('Distribusi Nilai Popularitas Drama Korea')
plt.xlabel('Nilai Popularitas')
plt.ylabel('Jumlah Drama')
plt.show()

# %% [markdown]
# Mengapa saya melakukan filter di kolom pop karena tanpa kalau filter, nilai 99999 yang merupakan sentinel value ikut terhitung dalam visualisasi sehingga histogram menunjukkan lonjakan tidak wajar di ujung kanan grafik. Nilai ini bukan nilai popularitas yang nyata melainkan hanya penanda bahwa drama tersebut belum memiliki data popularitas, sehingga kalau dibiarkan akan mendistorsi distribusi data yang sebenarnya dan menghasilkan interpretasi yang menyesatkan. Dengan memfilter nilai tersebut, distribusi popularitas drama Korea yang sesungguhnya dapat terlihat dengan lebih akurat dan dapat diinterpretasikan dengan tepat.

# %% [markdown]
#  ### **Insight**
#
# Dari histogram di atas, distribusi nilai popularitas drama Korea menunjukkan pola right-skewed, mayoritas drama menumpuk di rentang nilai popularitas 0–2000 dengan lebih dari 400 drama di kelompok pertama. Semakin tinggi nilai popularitas, semakin sedikit drama yang berhasil mencapainya. Ini menunjukkan bahwa hanya sebagian kecil drama yang berhasil meraih popularitas tinggi, sementara sebagian besar drama bersaing ketat di rentang popularitas rendah hingga menengah.

# %% [markdown]
# ### **Action**
#
# Pola distribusi ini mengkonfirmasi bahwa industri drama Korea sangat kompetitif, mayoritas drama tidak berhasil keluar dari rentang popularitas rendah. Platform sebaiknya fokus mengidentifikasi karakteristik drama yang berhasil menembus popularitas di atas 5000, karena drama-drama di rentang tersebut sudah termasuk kategori minoritas yang berhasil menonjol. Analisis lebih lanjut terhadap sutradara dan screenwriter dari drama-drama populer tersebut dapat menjadi dasar keputusan investasi konten yang lebih terarah ke depannya.

# %% [markdown]
# ## V **Box Plot** V

# %%
df['screenwriter_clean'] = df['screenwriter'].str.findall(r"'(.*?)'")
df_exploded_sw = df.explode('screenwriter_clean')


top10_tahun = df_exploded_sw['screenwriter_clean'].value_counts().head(10).index
df_top10 = df_exploded_sw[df_exploded_sw['screenwriter_clean'].isin(top10_tahun)]
df_top10= df_top10[df_top10['pop'] < 99999]  # filter sentinel value

plt.figure(figsize=(12, 7)) # Ukuran figure
sns.boxplot(x='screenwriter_clean', y='pop', data=df_top10, palette='PuRd', order=top10_tahun, hue='screenwriter_clean', legend=False)
plt.title('Distribusi Nilai Popularitas Berdasarkan Screenwriter (Top 10)', fontsize=16) # Judul
plt.xlabel('Screenwriter', fontsize=12) # X Keterangan
plt.ylabel('Nilai Popularitas', fontsize=12) # Y Keterangan
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Alasan melakukan explode karena kolom screenwriter menyimpan data dalam format string list seperti "['Kim Eun Hee', 'Lee Seul']", artinya satu baris bisa berisi lebih dari satu nama screenwriter. Tanpa explode, setiap kombinasi nama akan dianggap sebagai satu kategori unik yang berbeda, sehingga screenwriter yang sama tapi muncul di drama berbeda tidak akan terhitung bersama. Dengan explode, setiap screenwriter mendapat baris sendiri sehingga analisis per screenwriter bisa dilakukan secara akurat dan adil.

# %% [markdown]
# Sama seperti histogram, nilai 99999 pada kolom pop adalah sentinel value yang bukan nilai popularitas nyata. Kalau dibiarkan, nilai tersebut akan muncul sebagai outlier ekstrem di box plot yang membuat skala sumbu Y sangat jauh ke atas sehingga distribusi data yang sesungguhnya menjadi sangat kecil dan tidak terbaca. Dengan memfilter nilai tersebut, box plot setiap screenwriter dapat menampilkan distribusi popularitas yang sebenarnya secara jelas dan informatif.

# %% [markdown]
#  ### **Insight**
#
#  Dari 10 screenwriter paling produktif, Choi Yo Ji dan Jung Soo Yoon menunjukkan distribusi nilai popularitas tertinggi dengan median di atas 3000 dan box yang lebar, artinya drama-drama mereka tidak hanya populer tapi juga konsisten menghasilkan nilai popularitas yang tinggi. Sebaliknya, Kim Eun Sook meskipun termasuk screenwriter produktif, distribusi popularitasnya sangat rendah dan sempit di bawah 200. Sementara Kim Soon Ok memiliki rentang distribusi yang sangat lebar, mengindikasikan bahwa kualitas popularitas dramanya tidak konsisten, ada yang sangat populer dan ada yang tidak.

# %% [markdown]
# ### **Action**
#
# Platform sebaiknya memprioritaskan drama dari Choi Yo Ji dan Jung Soo Yoon karena keduanya terbukti secara historis menghasilkan drama dengan popularitas tinggi dan konsisten. Kim Soon Ok bisa dipertimbangkan dengan selektif, perlu ditelaah lebih lanjut drama mana yang berhasil dan mana yang tidak sebelum mengambil keputusan kolaborasi. Sementara screenwriter dengan distribusi popularitas rendah seperti Kim Eun Sook sebaiknya dikaji ulang strateginya sebelum diprioritaskan untuk promosi konten.

# %% [markdown]
# ## V **Scatter Plot** V

# %%
df_filtered = df[(df['rank'] != 99999) & (df['pop'] != 99999)] # filter sentinel value

plt.figure(figsize=(10, 6))
plt.scatter(df_filtered['total_days_aired'], df_filtered['rank'], alpha=0.7, color='#FF1493')
plt.title('Hubungan Durasi Tayang dan Rank Drama Korea', fontsize=16)
plt.xlabel('Total Hari Tayang', fontsize=12)
plt.ylabel('Rank', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Alasan saya melakukan filter karena kolom rank dan pop sama-sama mengandung nilai 99999 sebagai sentinel value. Kalau tidak difilter, titik-titik dengan nilai 99999 akan muncul di bagian paling atas dan paling kanan scatter plot, jauh dari sebaran data yang sesungguhnya, sehingga skala sumbu X dan Y menjadi sangat lebar dan membuat titik-titik data yang valid terlihat sangat kecil dan menumpuk di satu sudut saja. Akibatnya pola hubungan antara rank dan pop yang ingin dilihat menjadi tidak terbaca dengan jelas. Dengan memfilter kedua nilai sentinel tersebut, scatter plot dapat menampilkan pola persebaran data yang sesungguhnya secara lebih informatif.

# %% [markdown]
#  ### **Insight**
#
#  Dari Scatter plot di atas menunjukkan dua kelompok titik yang sangat jelas, drama dengan rank rendah (0–10.000) yang berarti populer, dan drama dengan rank tinggi (40.000–65.000) yang berarti kurang populer. Mayoritas drama terkonsentrasi di rentang 0–100 hari tayang, dan di kedua kelompok rank tersebut drama dengan durasi tayang pendek maupun panjang sama-sama bisa masuk, artinya tidak ada korelasi yang jelas antara durasi tayang dan rank. Drama yang tayang lama tidak otomatis mendapat rank lebih baik.

# %% [markdown]
# ### **Action**
#
# Temuan ini mempertegas bahwa durasi tayang bukan faktor penentu popularitas drama Korea. Platform dan produsen konten tidak perlu memperpanjang masa tayang drama semata-mata untuk mendongkrak popularitas, karena data historis 2015–2023 tidak mendukung strategi tersebut. Keputusan bisnis terkait promosi dan rekomendasi konten sebaiknya didasarkan pada faktor-faktor lain yang terbukti lebih berpengaruh terhadap popularitas drama.

# %% [markdown]
# ## V **Bubble Chart** V

# %%
df['duration'] = df['duration'].astype('int64')
df_filtered_bc = df[(df['rank'] != 99999) & (df['pop'] != 99999)]

plt.figure(figsize=(12, 8))
sns.scatterplot(x='rank', y='pop', size='duration', hue='year', data=df_filtered_bc,
                sizes=(50, 1000), alpha=0.7, palette='gist_rainbow')
plt.title('Hubungan Rank dan Popularitas Drama Korea (Ukuran: Durasi, Warna: Tahun)', fontsize=16)
plt.xlabel('Rank', fontsize=12)
plt.ylabel('Popularitas', fontsize=12)
plt.grid(True)
plt.legend(title='', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Alasan saya mengganti tipe data pada kolom 'duration' karena kolom 'duration' bertipe Int64 (nullable integer pandas) yang tidak kompatibel dengan seaborn saat digunakan sebagai parameter size pada bubble chart. Seaborn membutuhkan tipe data numerik standar untuk menghitung dan merender ukuran gelembung, sedangkan Int64 adalah tipe khusus pandas yang tidak dikenali oleh seaborn secara langsung. Dengan mengubahnya ke int64 (integer NumPy biasa), seaborn dapat membaca dan memproses nilai durasi dengan benar untuk menentukan ukuran setiap gelembung.

# %% [markdown]
# Sama seperti scatter plot, kolom rank dan pop mengandung nilai 99999 sebagai sentinel value. Kalau tidak difilter, gelembung-gelembung dengan nilai 99999 akan muncul di posisi ekstrem pada visualisasi sehingga skala sumbu menjadi sangat lebar dan pola hubungan antara rank, popularitas, dan durasi yang ingin dilihat menjadi tidak terbaca. Dengan memfilter nilai tersebut, persebaran gelembung data yang sesungguhnya dapat terlihat lebih jelas dan informatif.

# %% [markdown]
# ### **Insight**
#
# Dari bubble chart di atas menunjukkan dua kelompok data yang sangat jelas. Kelompok pertama di kiri bawah yaitu drama dengan rank rendah (0–10000) dan popularitas bervariasi (0–16000), inilah drama-drama yang berhasil meraih popularitas terbaik. Kelompok kedua di kanan yaitu drama dengan rank tinggi (40000–65000) yang nilai popularitasnya justru juga tinggi, ini terlihat paradoks namun mengingatkan kembali bahwa semakin kecil nilai rank semakin bagus, semakin kecil nilai pop semakin populer. Dari sisi ukuran gelembung, drama dengan durasi lebih panjang (gelembung besar) tersebar merata di kedua kelompok, menunjukkan durasi per episode tidak menentukan posisi popularitas sebuah drama.

# %% [markdown]
# ### **Action**
#
# Dua kelompok yang terpisah jelas ini mengindikasikan bahwa drama Korea cenderung terbagi menjadi 2(berhasil populer atau tidak sama sekali), dengan sangat sedikit yang berada di tengah. Platform sebaiknya fokus pada karakteristik drama di kelompok kiri bawah yang terbukti berhasil meraih rank dan popularitas terbaik, dan menjadikannya sebagai benchmark dalam mengevaluasi potensi drama baru sebelum diprioritaskan untuk promosi.

# %% [markdown]
# ## V **Heat Map** V

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['year', 'tot_eps', 'duration', 'rank', 'pop', 'total_days_aired']].corr(),
            annot=True,
            cmap='YlGnBu',
            fmt='.2f')
plt.title('Korelasi Antar Kolom Numerik Drama Korea')
plt.show()

# %% [markdown]
#  ### **Insight**
#
#  Dari heat map diatas, korelasi paling kuat ditemukan antara rank dan pop (0.77), menunjukkan bahwa drama dengan rank bagus cenderung juga memiliki nilai popularitas yang baik, mengkonfirmasi bahwa kedua kolom ini mengukur hal yang saling berkaitan. Korelasi negatif yang cukup kuat juga terlihat antara duration dan rank (-0.53) serta duration dan pop (-0.49), yang mengindikasikan bahwa drama dengan durasi per episode lebih panjang cenderung memiliki rank dan popularitas yang lebih baik. Sementara itu tot_eps dan total_days_aired (0.58) berkorelasi positif, ini wajar karena drama dengan lebih banyak episode otomatis tayang lebih lama.

# %% [markdown]
# ### **Action**
#
# Korelasi kuat antara rank dan pop mengkonfirmasi bahwa kedua kolom ini saling mendukung sebagai indikator popularitas dan tidak redundan satu sama lain. Drama dengan durasi per episode lebih panjang secara historis cenderung lebih populer, sehingga pertimbangan durasi per episode dapat menjadi salah satu faktor dalam perencanaan produksi drama baru ke depannya. Korelasi positif antara tot_eps dan total_days_aired juga dapat dimanfaatkan sebagai pertimbangan jadwal tayang, platform dapat memperkirakan berapa lama sebuah drama akan tayang hanya berdasarkan jumlah episodenya, sehingga memudahkan perencanaan slot tayang dan strategi promosi konten yang lebih terstruktur. Sementara itu, rendahnya korelasi antara year dengan semua kolom lain mengindikasikan bahwa tidak perlu membatasi rekomendasi konten berdasarkan tahun rilis, drama lama yang memiliki rank dan popularitas baik tetap layak direkomendasikan kepada penonton karena kualitasnya tidak bergantung pada seberapa baru drama tersebut dirilis.

# %% [markdown]
# # 5.**Menyimpan File**

# %%
df.to_csv('[Bersih]Drakor.csv', index=False)
